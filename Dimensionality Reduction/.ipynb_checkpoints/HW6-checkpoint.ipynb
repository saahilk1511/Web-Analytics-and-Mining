# %%
import warnings
warnings.filterwarnings('ignore')

import nest_asyncio # It manages running of all coroutines, tasks, callbacks
nest_asyncio.apply() # To avoid RuntimeError: This event loop is already running

import time
import twint
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Download at least 100 tweets each for keywords “booster shot” and “covid-19”

# %%
def get_tweets(word):
    
    c=twint.Config()
    c.Pandas=True
    c.Search=word
    c.Hide_output=True
    c.Limit=100
    c.Lang="en"

    twint.run.Search(c)
    df = twint.storage.panda.Tweets_df
    return df["tweet"]

# %%
tweets = list(get_tweets("booster shot"))[0:100]
tweets.extend(list(get_tweets("covid-19"))[0:100])
len(tweets)
# Out:
# 200

# %%
df = pd.DataFrame()
df["tweets"] = tweets

my_list = []
my_list.extend(["booster shot"] * 100)
my_list.extend(["covid-19"] * 100)

df["target_class"] = my_list

# %%
df.head()
# Out:
#                                               tweets  target_class
# 0  Is this the City's version of "Hollywood Squar...  booster shot
# 1  Booster shot done. I ouch.  https://t.co/0bxI1...  booster shot
# 2  Heres to hoping the booster doesn’t knock me o...  booster shot
# 3  @vatsofcats @MaddingtonRuth i have my booster ...  booster shot
# 4  @OnlineMathsT @BornJa21 @maryeffrancis @kapaha...  booster shot

# %%
df.tail()
# Out:
#                                                 tweets target_class
# 195  Overview of COVID-19 in Niagara as of Nov. 22 ...     covid-19
# 196  Europe: COVID-19 developments as of November 2...     covid-19
# 197  Attention #RedBankNJ residents! The #MonmouthC...     covid-19
# 198  Children aged 5-11 years are now being recomme...     covid-19
# 199  Why did Sick Kids hospital offer this "Myocard...     covid-19

# %% [markdown]
# ## Text Pre-processing

# %%
from nltk.corpus import stopwords 
from nltk.stem import WordNetLemmatizer
import re 
stop_words = set(stopwords.words('english'))

lemmer = WordNetLemmatizer()

def prep(x):
  
    x = str(x)
    # Lower case
    x = x.lower()
    
    # Remove punctuation
    x = re.sub(r'[^\w\s]', '', x)
    
    # Remove numbers
    x = re.sub(r'\d+', '', x)
     
    # Remove stopwords and lemmatize
    x = [lemmer.lemmatize(w) for w in x.split() if w not in stop_words]
    
    return ' '.join(x)

df['clean_tweets'] = df['tweets'].apply(prep)
df.head()
# Out:
#                                               tweets  target_class  \
# 0  Is this the City's version of "Hollywood Squar...  booster shot
# 1  Booster shot done. I ouch.  https://t.co/0bxI1...  booster shot
# 2  Heres to hoping the booster doesn’t knock me o...  booster shot
# 3  @vatsofcats @MaddingtonRuth i have my booster ...  booster shot
# 4  @OnlineMathsT @BornJa21 @maryeffrancis @kapaha...  booster shot
#
#                                         clean_tweets
# 0  city version hollywood square top nyc doctor d...
# 1              booster shot done ouch httpstcobxixwx
# 2   here hoping booster doesnt knock as like nd shot
# 3  vatsofcats maddingtonruth booster shot soon im...
# 4  onlinemathst bornja maryeffrancis kapahater ja...

# %% [markdown]
# ## Vectorization & creating TF-IDF score

# %%
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer

# %%
bow_transformer = CountVectorizer().fit(df["clean_tweets"])
# Print total number of vocab words
print(len(bow_transformer.vocabulary_))
# Out:
# 1615

# %%
bow = bow_transformer.transform(df["clean_tweets"])
print('Shape of Sparse Matrix: ', bow.shape)
print('Amount of Non-Zero occurences: ', bow.nnz)
# Out:
# Shape of Sparse Matrix:  (200, 1615)
# Amount of Non-Zero occurences:  3062

# %%
from sklearn.feature_extraction.text import TfidfTransformer

tfidf_transformer = TfidfTransformer().fit(bow)
tfidf = tfidf_transformer.transform(bow)
print(tfidf.shape)
# Out:
# (200, 1615)

# %%
print(tfidf)
# Out:
#   (0, 1538)	0.19323606425401701
#   (0, 1528)	0.22292456788014417
#   (0, 1461)	0.24029122920395263
#   (0, 1357)	0.24029122920395263
#   (0, 1312)	0.0731640547759561
#   (0, 1289)	0.1635475606278898
#   (0, 1034)	0.24029122920395263
#   (0, 991)	0.24029122920395263
#   (0, 911)	0.20104516216540982
#   (0, 677)	0.24029122920395263
#   (0, 643)	0.24029122920395263
#   (0, 619)	0.24029122920395263
#   (0, 492)	0.14862907744595902
#   (0, 378)	0.31389012484123896
#   (0, 368)	0.18091422195169826
#   (0, 325)	0.24029122920395263
#   (0, 301)	0.21060272557782544
#   (0, 261)	0.22292456788014417
#   (0, 239)	0.22292456788014417
#   (0, 234)	0.22292456788014417
#   (0, 158)	0.07064383043214097
#   (0, 78)	0.1635475606278898
#   (1, 1312)	0.17076741739399925
#   (1, 1065)	0.560847984153463
#   (1, 641)	0.560847984153463
#   :	:
#   (198, 652)	0.24323251966211948
#   (198, 647)	0.24323251966211948
#   (198, 538)	0.2746855307409836
#   (198, 297)	0.06464862964051206
#   (198, 228)	0.36625741350445973
#   (198, 197)	0.24323251966211948
#   (198, 101)	0.24323251966211948
#   (198, 34)	0.2035060602144011
#   (199, 1516)	0.17774000499321715
#   (199, 1430)	0.21883950024073046
#   (199, 1318)	0.2524616779719855
#   (199, 1226)	0.23850721340609657
#   (199, 1095)	0.2721293911373517
#   (199, 1042)	0.2524616779719855
#   (199, 989)	0.2721293911373517
#   (199, 980)	0.2721293911373517
#   (199, 834)	0.21136218272447221
#   (199, 796)	0.2721293911373517
#   (199, 746)	0.2721293911373517
#   (199, 624)	0.22768328978310937
#   (199, 574)	0.2721293911373517
#   (199, 297)	0.07232911226827436
#   (199, 247)	0.2721293911373517
#   (199, 228)	0.20488503567484148
#   (199, 102)	0.2721293911373517

# %% [markdown]
# ## Dimensionality Reduction
# 1. Principal Component Analysis (PCA)
# 2. T-distributed Stochastic Neighbor Embedding (t-SNE)
# 3. Uniform Manifold Approximation and Projection (UMPA)

# %% [markdown]
# ### 1. Principal Component Analysis (PCA)

# %%
start = time.time()
from sklearn.decomposition import IncrementalPCA
pca = IncrementalPCA(n_components = 2)
X_pca = pca.fit_transform(tfidf)
end_pca = (time.time() - start)
print('Duration: {} seconds'.format(end_pca))

print("\nExplained Variance Ratio:",pca.explained_variance_ratio_)
print("Noise Variance:",round(pca.noise_variance_,3))
# Out:
# Duration: 0.0948641300201416 seconds
#
# Explained Variance Ratio: [0.01993929 0.01430178]
# Noise Variance: 0.005

# %%
plt.figure(figsize=(15,7))
sns.scatterplot(X_pca[:,0],X_pca[:,1],hue = df["target_class"])
plt.xlabel('First principal component')
plt.ylabel('Second Principal Component')
plt.legend()
plt.show()

# %% [markdown]
# ### 2. T-distributed Stochastic Neighbor Embedding (t-SNE)

# %%
start = time.time()
from sklearn.manifold import TSNE
# With perplexity = 50 and without PCA as pre-processing 
tsne = TSNE(n_components=2, verbose=1, perplexity=50, 
            n_iter=500, random_state=42).fit_transform(tfidf) 

end_tsne_1 = (time.time() - start)
print('\nDuration: {} seconds'.format(end_tsne_1))
# Lower the KL divergence value, the better we have matched the true distribution with our approximation.

plt.figure(figsize=(15,7))
sns.scatterplot(tsne[:,0],tsne[:,1],hue = df["target_class"])
plt.xlabel('First component')
plt.ylabel('Second Component')
plt.legend()
plt.show()
# Out:
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 200 samples in 0.000s...
# [t-SNE] Computed neighbors for 200 samples in 0.004s...
# [t-SNE] Computed conditional probabilities for sample 200 / 200
# [t-SNE] Mean sigma: 0.234323
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 62.977631
# [t-SNE] KL divergence after 500 iterations: 0.868791
#
# Duration: 0.3167738914489746 seconds

# %%
# With perplexity = 50 and PCA as pre-processing 
start = time.time()
tsne = TSNE(n_components=2, verbose=1, perplexity=50, 
            n_iter=500, random_state=42).fit_transform(X_pca) 

end_tsne_2 = (time.time() - start)
print('\nDuration: {} seconds'.format(end_tsne_2))

# Lower the KL divergence value, the better we have matched the true distribution with our approximation.
# Similar labels are clustered together, even though there are still data points on top of each other

plt.figure(figsize=(15,7))
sns.scatterplot(tsne[:,0],tsne[:,1],hue = df["target_class"])
plt.xlabel('First component')
plt.ylabel('Second Component')
plt.legend()
plt.show()
# Out:
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 200 samples in 0.000s...
# [t-SNE] Computed neighbors for 200 samples in 0.003s...
# [t-SNE] Computed conditional probabilities for sample 200 / 200
# [t-SNE] Mean sigma: 0.035560
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 51.541954
# [t-SNE] KL divergence after 500 iterations: 0.113693
#
# Duration: 0.24922704696655273 seconds

# %% [markdown]
# ### 3. Uniform Manifold Approximation and Projection (UMAP)

# %%
# It can be applied directly to sparse matrices thereby eliminating the need to applying any Dimensionality reduction
# such as PCA or Truncated SVD(Singular Value Decomposition) as a prior pre-processing step.

start = time.time()
import umap
embedding = umap.UMAP(n_neighbors=30, n_components=2, metric='jaccard',
                      n_epochs= 500, verbose=1, random_state=42).fit_transform(tfidf)

end_umap_1 = (time.time() - start)
print('\nDuration: {} seconds'.format(end_umap_1))


plt.figure(figsize=(15,7))
sns.scatterplot(embedding[:,0],embedding[:,1],hue = df["target_class"])
plt.xlabel('First component')
plt.ylabel('Second Component')
plt.legend()
plt.show()
# Out:
# Init Plugin
# Init Graph Optimizer
# Init Kernel
# UMAP(angular_rp_forest=True, metric='jaccard', n_epochs=500, n_neighbors=30, random_state=42, verbose=1)
# Mon Nov 22 12:03:57 2021 Construct fuzzy simplicial set
# Mon Nov 22 12:03:58 2021 Finding Nearest Neighbors
# OMP: Info #271: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# Mon Nov 22 12:03:58 2021 Finished Nearest Neighbor Search
# Mon Nov 22 12:03:59 2021 Construct embedding
# Epochs completed:   0%|            0/500 [00:00]
# Mon Nov 22 12:04:00 2021 Finished embedding
#
# Duration: 6.592377185821533 seconds

# %%
# Low values of n_neighbours forces UMAP to focus on very local structures 
# while the higher values will make UMAP focus on the larger neighbourhoods.

start = time.time()
import umap
embedding = umap.UMAP(n_neighbors=250, n_components=2, metric='jaccard',
                      n_epochs= 500, verbose=1, random_state=42).fit_transform(tfidf)

end_umap_2 = (time.time() - start)
print('\nDuration: {} seconds'.format(end_umap_2))

plt.figure(figsize=(15,7))
sns.scatterplot(embedding[:,0],embedding[:,1],hue = df["target_class"])
plt.xlabel('First component')
plt.ylabel('Second Component')
plt.legend()
plt.show()
# Out:
# UMAP(angular_rp_forest=True, metric='jaccard', n_epochs=500, n_neighbors=250, random_state=42, verbose=1)
# Mon Nov 22 12:08:32 2021 Construct fuzzy simplicial set
# Mon Nov 22 12:08:32 2021 Finding Nearest Neighbors
# Mon Nov 22 12:08:32 2021 Finished Nearest Neighbor Search
# Mon Nov 22 12:08:32 2021 Construct embedding
# Epochs completed:   0%|            0/500 [00:00]
# Mon Nov 22 12:08:35 2021 Finished embedding
#
# Duration: 3.681101083755493 seconds

# %%
data = {'DR_Method':['PCA', 'TSNE', 'TSNE_PCA', 'UMAP_30', 'UMAP_250'],
        'Time_Taken':[end_pca, end_tsne_1, end_tsne_2, end_umap_1, end_umap_2]}

df_time = pd.DataFrame(data)
df_time.sort_values(by = "Time_Taken", ignore_index=True)
# Out:
#   DR_Method  Time_Taken
# 0       PCA    0.094864
# 1  TSNE_PCA    0.249227
# 2      TSNE    0.316774
# 3  UMAP_250    3.681101
# 4   UMAP_30    6.592377
